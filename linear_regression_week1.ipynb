# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Aim is to predict the marks of students of the test data

# %%
# Use the file namd 'training data' to train the model

#from google.colab import files
#uploaded = files.upload()

data = pd.read_excel('Training data.xlsx')
x_train = np.array(data.iloc[:,0:8])
y_train = np.array(data.iloc[:,8]).reshape(-1,1)

# Try plotting y_train with different features
# To get an idea whether to add some features or not
# Add some features if required in x_train

# Also do label encoding for features not represented in numbers
# refer the link if not know : https://youtu.be/589nCGeWG1w?si=t2Wa7LgbUOO4RooM

def feature_changing(x_train):

  x_train[:,0] = (x_train[ : ,0] == 'yes').astype(int)
  x_train[:,1] = (x_train[ : ,1] == 'M').astype(int)

  # ---------
    # Your code here
  # ---------
  return x_train

x_train = feature_changing(x_train)
# Out:
#      <input type="file" id="files-b1e4233c-d76c-4a13-bdc5-14c4aa0ce184" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1e4233c-d76c-4a13-bdc5-14c4aa0ce184">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def z_score(x_train):

  x_mean_new = np.mean(x_train , axis = 0)

  x_std_new = np.std(x_train , axis = 0)

  x_train_new = (x_train - x_mean_new) / x_std_new

  # ---------
    # write the code for feature scaling here
    # Your code here
  # ---------

  return x_train_new,x_std_new,x_mean_new

# %%
def cost(x_train,y_train,w,b):

  y_approx = np.dot(x_train , w) + b

  loss = 0.5 * np.mean( (y_approx - y_train)**2 )

    # ---------
    # Your code here
    # Use mean square error as cost function
    # return cost
  # ---------

  return loss

# %%
def gradient_descent(x_train,y_train,w,b):

  alpha = 0.001

  y_approx = np.dot (x_train , w) + b

  dw = (1 / 8 ) * np.dot(x_train.T , ( y_approx - y_train ))
  db = (1 / 8 ) * np.sum (y_approx - y_train)

  w_new = w - alpha * dw
  b_new = b - alpha * db

  # ---------
    # Your code here
    # Choose learning rate yourself
  # ---------

  return w_new , b_new

# %%
x_train = x_train.astype(np.float64)
x_train,x_std,x_mean = z_score(x_train)

np.random.seed(2147483647)
w = np.random.randn(x_train.shape[1],1)
b = np.random.randn(1)

old_cost = 0

while abs(old_cost - cost(x_train,y_train,w,b))>0.00001:
  old_cost = cost(x_train,y_train,w,b)
  w,b = gradient_descent(x_train,y_train,w,b)

#from google.colab import files
#uploaded = files.upload()
x_predict = pd.read_excel('Test data.xlsx').iloc[:,:8].to_numpy()
x_predict = feature_changing(x_predict)
x_predict = (x_predict - x_mean)/x_std
ans = pd.read_excel('Test data.xlsx').iloc[:,8].to_numpy()

y_predict = np.dot(x_predict,w) + b


accuracy = 0
for dim in range(len(ans)):
  if abs(y_predict[dim]-ans[dim])<0.5: # do not change the tolerance as you'll be checked on +- 0.5 error only
    accuracy += 1
accuracy = round(accuracy*100/200.0,2)
ok = 'Congratulations' if accuracy>95 else 'Optimization required'
print(f"{ok}, your accuracy is {accuracy}%")
# Out:
#      <input type="file" id="files-bea3211c-ce3d-4403-ab9d-1458d5d26309" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bea3211c-ce3d-4403-ab9d-1458d5d26309">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
